# %% [markdown]
# # **`matplotlib` : librairie pour la représentation graphique**

# %% [markdown]
# ## **`matplotlib`?**
#
# - La librairie `matplotlib` est **la** bibliothèque graphique de Python
#
# - Étroitement liée à `numpy` et `scipy`
#
# - Grande variété de **format de sortie (`png`, `pdf`, `svg`, `eps`, `pgf`)** ainsi que support de **$\LaTeX$** pour le texte
#
# - Tous les aspects d'une figure (taille, position,...) peuvent être contrôlés d'un point de vue *programmatique* $\to$ **reproductibilité** des figures et des résultats scientifiques

# %% [markdown]
# ## **Installation & importation de `matplotlib`**
#
# - Installation *via* `pip`
#
# ```sh
# pip install matplotlib
# ```
#
# - Convention d'importation

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.__version__
# Out:
# '3.8.0'

# %% [markdown]
# ## **Première figure sous `matplotlib`**

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 3 * np.pi, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ## ***Kozmetix* sous `matplotlib`**

# %% [markdown]
# ### **Lignes, marqueurs : styles & couleurs**

# %%
plt.plot(x, x + 0, linestyle="solid")

plt.plot(x, x + 1, linestyle="dashed")

plt.plot(x, x + 2, linestyle="dashdot")

plt.plot(x, x + 3, linestyle="dotted")

for i, ls in enumerate(["-", "--", "-.", ":"]):
    plt.plot(x, x + 4 + i, linestyle=ls)

# %%
# En spécifiant le nom de la couleur
plt.plot(x, np.sin(x - 0), color="blue")

# Nom raccourci (rgbcmyk)
plt.plot(x, np.sin(x - 1), color="g")

# Échelle de gris [0; 1]
plt.plot(x, np.sin(x - 2), color="0.75")

# Code héxadécimal (RRGGBB)
plt.plot(x, np.sin(x - 3), color="#FFDD44")

# RGB tuple [0; 1]
plt.plot(x, np.sin(x - 4), color=(1.0, 0.2, 0.3))

# Couleur du cycle C0-9
plt.plot(x, np.sin(x - 5), color="C4");

# %%
x = np.linspace(0, 3 * np.pi, 30)

plt.plot(x, np.sin(x), "o")

plt.plot(
    x,
    np.sin(x),
    "p",
    markersize=15,
    markerfacecolor="pink",
    markeredgecolor="gray",
    markeredgewidth=2,
    alpha=0.5,
);

# %%
for marker in ["o", ".", ",", "x", "+", "v", "^", "<", ">", "s", "d"]:
    plt.plot(np.random.rand(10), np.random.rand(10), marker)

# %% [markdown]
# Il est finalement possible de combiner style & couleur au sein d'une syntaxe minimaliste

# %%
plt.plot(x, x + 0, "-og")

plt.plot(x, x + 1, "--xc")

plt.plot(x, x + 2, "-..k")

plt.plot(x, x + 3, ":sr");

# %% [markdown]
# Pour découvrir l'ensemble des options d'affichage `plt.plot?` ou `help(plt.plot)=` ou menu `Help>Show Contextual Help` (`CTRL+I`)

# %% [markdown]
# ### **Axes : échelle, limites & *ticks***

# %%
x = np.linspace(0, 3 * np.pi, 100)

plt.plot(x, np.sin(x))

plt.xscale("log")

plt.yscale("log")

plt.loglog(x, np.sin(x), ".");

# %% [markdown]
# Pour découvrir l'ensemble des options d'affichage `plt.xscale?` ou `help(plt.xscale)`

# %%
x = np.linspace(0, 3 * np.pi, 100)
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5)

plt.axis([11, -1, 1.5, -1.5])

plt.axis("tight")

plt.axis("equal");

# %% [markdown]
# Pour découvrir l'ensemble des options d'affichage `plt.axis?` ou `help(plt.axis)`

# %%
plt.plot(x, np.sin(x))

plt.xticks([0, np.pi / 2, np.pi, 3 * np.pi / 2, 2 * np.pi, 5 * np.pi / 2, 3 * np.pi])
plt.yticks([-1, 0, +1])

plt.xticks(
    [0, np.pi / 2, np.pi, 3 * np.pi / 2, 2 * np.pi, 5 * np.pi / 2, 3 * np.pi],
    [r"$0$", r"$\pi/2$", r"$\pi$", r"$3\pi/2$", r"$2\pi$", r"$5\pi/2$", r"$3\pi$"],
);

# %% [markdown]
# Le prefixe `r` pour *raw-text* indique que la chaîne de caractères doit être traiter sans échapper les caractères précédés de `\`

# %% [markdown]
# - Accéder aux axes de la figure (`gca` $\equiv$ `get current axis`)

# %%
plt.plot(x, np.sin(x))

plt.grid()

ax = plt.gca()

ax.spines["right"].set_color(None)

ax.spines["top"].set_color(None)

ax.spines["bottom"].set_position(("data", 0))

# %% [markdown]
# - Duppliquer les axes (à droite ou en haut)

# %%
r = np.linspace(0, 5, 100)
plt.plot(r, np.pi * r**2, color="C0")

ax = plt.gca()
for label in ax.get_yticklabels():
    label.set_color("C0")

plt.twinx()

plt.plot(r, 4 / 3 * np.pi * r**3, color="C1")
ax = plt.gca()
for label in ax.get_yticklabels():
    label.set_color("C1")

# %% [markdown]
# ### ***Labelling* : titre, axes, légendes et autres annotations**

# %% [markdown]
# - Nommer la figure et ses axes

# %%
x = np.linspace(0, 3 * np.pi, 100)
plt.plot(x, np.sin(x))

plt.title("Variation de la fonction sinus")
plt.xlabel(r"$\theta$")
plt.ylabel(r"$\sin\theta$");

# %% [markdown]
# - Ajouter une légende

# %%
x = np.linspace(0, 3 * np.pi, 100)
plt.plot(x, np.sin(x), label=r"$\sin\theta$")
plt.plot(x, np.cos(x), label=r"$\cos\theta$")
plt.axis("equal")

plt.legend()

plt.legend(loc="upper left")

plt.legend(loc="lower center", ncol=2);

# %% [markdown]
# Pour découvrir l'ensemble des options d'affichage `plt.legend?` ou `help(plt.legend)`

# %%
x = np.linspace(0, 3 * np.pi, 100)
plt.plot(x, np.sin(x), label=r"$\sin\theta$")
plt.plot(x, np.cos(x), label=r"$\cos\theta$")
plt.axis("equal")
plt.legend(loc="lower center", ncol=2)

plt.text(0, 3, "Matplotlib rocks !")

plt.annotate(
    r"$\cos\left(\frac{\pi}{2}\right)=0$",
    xy=(np.pi / 2, np.cos(np.pi / 2)),
    xytext=(3, 2),
    arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"),
);

# %% [markdown]
# ## **Les différents modes de représentation**

# %% [markdown]
# ### ***Scatter plot***

# %%
x = np.linspace(0, 3 * np.pi, 30)
plt.scatter(x, np.sin(x), marker="o")

plt.plot(x, np.cos(x), "o", color="orange");

# %% [markdown]
# - Le mode *scatter* permet de contrôler (taille, couleur) chaque point/marqueur individuellement

# %%
rng = np.random
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.grid()
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap="viridis")
plt.colorbar();

# %% [markdown]
# ### **Barres d'erreur**

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt="o")
plt.plot(x, np.sin(x))

plt.errorbar(x, y, yerr=dy, fmt="o", color="black", ecolor="lightgray", elinewidth=3, capsize=0)

plt.fill_between(x, np.sin(x) - dy, np.sin(x) + dy, alpha=0.2, color="gray");

# %% [markdown]
# ### **Histogramme 1D**

# %%
data = np.random.randn(1000)
plt.hist(data)

plt.figure()
plt.hist(data, bins=30, density=True);

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype="stepfilled", alpha=0.5, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# ### **Histogramme 2D**

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

plt.hist2d(x, y, bins=30, cmap="Blues")
plt.colorbar();

# %% [markdown]
# ### **Contours & densités**
#
#   \begin{align*}
#     z = f(x,y) =& \sin^{10} x + \cos(x\cdot y)\cdot\cos x\\
#     =&\sin^{10}\begin{bmatrix}
#     x_0&\cdots
#     \end{bmatrix}+\cos\left(\begin{bmatrix}
#         x_0&\cdots
#       \end{bmatrix}\cdot\begin{bmatrix}
#     y_0\\\vdots\end{bmatrix}\right)\cdot\cos\begin{bmatrix}
#         x_0&\cdots
#       \end{bmatrix}
#   \end{align*}

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(x * y) * np.cos(x)


x = np.linspace(0, 5, 500)
y = np.linspace(0, 5, 500)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

contours = plt.contour(X, Y, Z, 3, colors="black")
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin="lower", cmap="RdGy", alpha=0.5)
plt.colorbar();

# %% [markdown]
# ### **Image 2D**

# %%
img = plt.imread("./data/pascal_parneix.jpg")

plt.imshow(img, cmap="gray")
plt.title("P. Parneix après le partiel d'Atomes & Molécules")

plt.scatter(255, 290, c="red", s=1000)
plt.title("P. Parneix après son anniversaire");

# %% [markdown]
# ### ***Subplot***
#
# - `matplotlib` permet une gestion relativement aisée du placement des figures et de leurs sous-figures

# %%
ax1 = plt.axes()

ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %% [markdown]
# avec `axes([x, y, w, h])` et **`x,y,w,h` exprimés en fraction du canevas initial**

# %%
x = np.linspace(-1, 1, 1000)
plt.plot(x, x**2, x, x**3)

inset = plt.axes([0.6, 0.2, 0.25, 0.25])

inset.plot(x, x**2, x, x**3)
inset.set_title("zoom x = 0")
inset.set_xlim(-0.2, +0.2)
inset.set_ylim(-0.005, +0.01);

# %% [markdown]
# - La commande `subplot` permet la génération **sous-figure par sous-figure** selon une représentation matricielle

# %%
plt.subplot(2, 3, 1)

plt.subplot(2, 3, 3)

plt.subplot(2, 3, 5);

# %% [markdown]
# - La commande `subplots` permet la génération de **l'ensemble des sous-figures** selon une représentation matricielle

# %%
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)

for i in range(2):
    for j in range(3):
        axes[i, j].text(0.5, 0.5, f"({i}, {j})", fontsize=18, ha="center")

plt.subplots_adjust(hspace=0, wspace=0)

# %% [markdown]
# - La commande `GridSpec` ne génère pas de figures ou sous figures mais facilite la gestion et notamment la fusion d'espaces réservés aux sous-figures

# %%
grid = plt.GridSpec(2, 3, hspace=0.4, wspace=0.4)

plt.subplot(grid[0, 0])

plt.subplot(grid[0, 1:])

plt.subplot(grid[1, :2])

plt.subplot(grid[1, 2]);

# %% [markdown]
# - Quelques exemples d'utilisation de `GridSpec`

# %%
x = np.linspace(0, 10, 100)
dy = 0.4
y = np.sin(x) + dy * np.random.randn(100)

grid = plt.GridSpec(4, 1, hspace=0, wspace=0)

main = plt.subplot(grid[0:3], xticklabels=[], xlim=[0, 10])
main.plot(x, np.sin(x), "r")
main.errorbar(x, y, yerr=dy, fmt="ok")
main.set(ylabel=r"$y$")

dev = plt.subplot(grid[3], xlim=[0, 10])
dev.errorbar(x, y - np.sin(x), yerr=dy, fmt="ok")
dev.plot([0, 10], [0, 0], "--r")
dev.set(ylabel=r"$y-y_\mathrm{model}$", xlabel=r"$\theta$");

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0, wspace=0)
main_ax = plt.subplot(grid[:-1, 1:], xticklabels=[], yticklabels=[])
y_hist = plt.subplot(grid[:-1, 0], xticklabels=[])
x_hist = plt.subplot(grid[-1, 1:], yticklabels=[])

# scatter points on the main axes
main_ax.plot(x, y, "ok", markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype="stepfilled", orientation="vertical", color="gray")
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype="stepfilled", orientation="horizontal", color="gray")
y_hist.invert_xaxis()

# %% [markdown]
# # **Les compléments à `matplotlib`**

# %% [markdown]
# ## **[`seaborn`](https://seaborn.pydata.org/index.html)**
#
# [`seaborn`](https://seaborn.pydata.org/index.html), tout en s'appuyant sur `matplotlib`, propose une interface simple pour traiter statistiquement des données numériques soit *via* des tableaux `numpy` soit directement à partir de données `pandas`. Le module est richement documenté et les tutoriels ou encore la [galerie d'exemples](https://seaborn.pydata.org/examples/index.html) permettent de se faire une idée plus précise des possibilités offertes par `seaborn`. L'installation se fait *via* `pip`

# %%
# %pip install seaborn

# %%
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load penguins dataset where penguins is a pandas dataframe
penguins = sns.load_dataset("penguins")

sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species");

# %% [markdown]
# ## **[`plotly`](https://plotly.com/python)**
#
# La librairie [`plotly`](https://plotly.com/python) est à la base une librairie `javascript`. Une interface `python` est proposée afin de tirer partie des avantages de la librairie notamment l'interactivité. Tout comme `seaborn`, `plotly` permet la manipulation d'objets de type `pandas.DataFrame` afin d'en visualiser les propriétés statistiques et d'exporter les graphiques vers des pages `html` dynamiques. Comme pour `seaborn`, l'installation peut se faire simplement *via* `pip`

# %%
# %pip install plotly

# %%
import plotly.express as px
import plotly.io as pio

pio.templates.default = "seaborn"

gapminder = px.data.gapminder()
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
px.violin(
    gapminder,
    x="continent",
    y="lifeExp",
    color="continent",
    labels={"lifeExp": "life expectancy at birth"},
).update_layout(showlegend=False)

# %% [markdown]
# Entre autres possibilités, `plotly` propose une couche d'animation relativement simple à mettre en oeuvre

# %%
px.scatter(
    gapminder,
    x="gdpPercap",
    y="lifeExp",
    animation_frame="year",
    animation_group="country",
    size="pop",
    color="continent",
    hover_name="country",
    log_x=True,
    size_max=55,
    range_x=[100, 100000],
    range_y=[25, 90],
    labels={
        "lifeExp": "life expectancy at birth",
        "gdpPercap": "per-capita gross domestic product in dollars",
    },
).update_layout(height=500)

# %% [markdown]
# De même, les données géographiques peuvent être assez simplement représentées sur des fonds de cartes pré-existants

# %%
import pandas as pd
import plotly.graph_objects as go

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/2014_us_cities.csv")
df["text"] = df["name"] + "<br>Population " + (df["pop"] / 1e6).astype(str) + " million"

fig = go.Figure()

limits = [(0, 2), (3, 10), (11, 20), (21, 50), (50, len(df))]
for i, limit in enumerate(limits):
    df_sub = df[limit[0] : limit[1]]
    fig.add_trace(
        go.Scattergeo(
            locationmode="USA-states",
            lon=df_sub["lon"],
            lat=df_sub["lat"],
            text=df_sub["text"],
            name="",
            marker=dict(
                size=df_sub["pop"] / 5000,
                line_color="rgb(40,40,40)",
                line_width=0.5,
                sizemode="area",
            ),
        )
    )

fig.update_layout(
    title_text="2014 US city populations",
    showlegend=False,
    geo=dict(scope="usa", landcolor="rgb(217, 217, 217)"),
    height=800,
)
